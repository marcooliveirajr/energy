# %% [markdown]
# # Bronze → Silver – Executor
#
# Orquestra a transformação de dados da camada **Bronze** para a camada **Silver** por domínio/fonte.
#
# - Lê configurações em `ingestion_configs/*.json` do domínio (ex.: financeiro/api_mxm)
# - Aplica DDL/schema quando necessário
# - Lê tabelas `brz_t_fin_*`, aplica limpeza e padronização, grava em `slv_fin_*` (Silver sem _t_)
# - Paths: `config/paths_and_prefixes.yaml` e `src.config.paths`

# %%
# Parâmetros do job (Widgets Databricks ou variáveis)
domain = "financeiro"  # Único domínio por enquanto
source = "api_mxm"
config_base_path = "financeiro/api_mxm/ingestion_configs"

# %%
# Listar e processar cada config Bronze → Silver do domínio
# import json
# from pathlib import Path
# base = Path('src/framework/bronze_to_silver')
# for cfg_file in (base / domain / source / 'ingestion_configs').glob('*.json'):
#     with open(cfg_file) as f:
#         cfg = json.load(f)
#     # Ler brz_t_fin_* → transformar → gravar slv_fin_*
#     print(cfg.get('source_table'), '->', cfg.get('table_name'))
pass  # Implementar leitura de configs e transformação Bronze → Silver (Delta)
