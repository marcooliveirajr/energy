# %% [markdown]
# # Raw → Bronze – Executor
#
# Orquestra a ingestão de dados **Raw** para a camada **Bronze** por domínio/fonte.
#
# - Lê configurações em `ingestion_configs/*.json` do domínio (ex.: financeiro/api_mxm)
# - Aplica DDL/schema quando necessário
# - Ingere da fonte (API MXM) e grava em tabelas `brz_t_fin_*`
# - Paths: `config/paths_and_prefixes.yaml` e `src.config.paths`

# %%
# Parâmetros do job (Widgets Databricks ou variáveis)
domain = "financeiro"  # Único domínio por enquanto
source = "api_mxm"
config_base_path = "financeiro/api_mxm/ingestion_configs"

# %%
# Listar e processar cada config de ingestão do domínio
# import json, os
# from pathlib import Path
# base = Path('src/framework/raw_to_bronze')
# for cfg_file in (base / domain / source / 'ingestion_configs').glob('*.json'):
#     with open(cfg_file) as f:
#         cfg = json.load(f)
#     # Chamar lógica de ingestão (API → Bronze) conforme cfg
#     print(cfg.get('table_name'), cfg.get('api_endpoint'))
pass  # Implementar leitura de configs e chamada à API MXM → gravar Delta Bronze
